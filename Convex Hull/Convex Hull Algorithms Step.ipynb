# %% [markdown]
# # Import module

# %%
from Jarvis_Algorithm_Step import *
from QuickHull_Algorithm_Step import *
from MergeHull_Algorithm_Step import *
import random
import time

# %% [markdown]
# # Random Dataset

# %%
random.seed(2012)
data = []
for i in range(20):
    data.append(point(random.randint(-100000, 100000), random.randint(-100000, 100000)))

# %% [markdown]
# # Jarvis Algorithm Implementation

# %%
hull_ja = convex_hull_ja(data, len(data))
display_ja(data, hull_ja)

# %% [markdown]
# # QuickHull Algorithm Implementation

# %%
hull_qh = convex_hull_qh(data, len(data))
display_qh(data, hull_qh)

# %% [markdown]
# # MergeHull Algorithm Implementation

# %%
hull_mh = convex_hull_mh(data)
display_mh(data, hull_mh)
